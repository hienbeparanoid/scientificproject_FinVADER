# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk

# %%
df = pd.read_csv('tsla_merged.csv')
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#      submission_id                                   submission_title  \
# 0          1abv5ee                           Routine Analysis of TSLA
# 1          1abv5ee                           Routine Analysis of TSLA
# 2          1abv5ee                           Routine Analysis of TSLA
# 3          1abv5ee                           Routine Analysis of TSLA
# 4          1abv5ee                           Routine Analysis of TSLA
# ...            ...                                                ...
# 4099       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4100       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4101       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4102       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4103       197p6vu  remember when elon pumped $TSLA instead of dum...
#
#                     date                                       comment_text  \
# 0    2024-01-27 06:48:36         This is such a generic and pointless post.
# 1    2024-01-27 19:02:34      thanks for summarizing yahoo finance I guess?
# 2    2024-01-27 06:25:13     Tesla is going to fall to between $100 & $150.
# 3    2024-01-28 05:04:35  How are they long-term resilient if they're do...
# 4    2024-01-27 07:20:17  Welcome to r/stockmarket.\n\nIt's all just bot...
# ...                  ...                                                ...
# 4099 2024-01-17 04:40:50                           Is he worth 20 Twitters?
# 4100 2024-01-17 00:53:22  Simply asked? Bruh, you went on a rant and cal...
# 4101 2024-01-17 01:06:35  haha "blue haired retar\*d" I like that. I'm g...
# 4102 2024-01-17 01:44:27          Your reading comprehension is impressive.
# 4103 2024-01-17 02:18:07                                        danke schön
#
#       upvotes
# 0          24
# 1           3
# 2          -8
# 3           1
# 4           5
# ...       ...
# 4099        1
# 4100        1
# 4101        1
# 4102       -1
# 4103       -1
#
# [4104 rows x 5 columns]

# %%
# Lọc DataFrame để chỉ giữ lại các dòng có 'date' sau hoặc bằng 1/1/2024
df = df[df['date'] >= '2024-01-01']
df
# Out:
#      submission_id                                   submission_title  \
# 0          1abv5ee                           Routine Analysis of TSLA
# 1          1abv5ee                           Routine Analysis of TSLA
# 2          1abv5ee                           Routine Analysis of TSLA
# 3          1abv5ee                           Routine Analysis of TSLA
# 4          1abv5ee                           Routine Analysis of TSLA
# ...            ...                                                ...
# 4099       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4100       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4101       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4102       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4103       197p6vu  remember when elon pumped $TSLA instead of dum...
#
#                     date                                       comment_text  \
# 0    2024-01-27 06:48:36         This is such a generic and pointless post.
# 1    2024-01-27 19:02:34      thanks for summarizing yahoo finance I guess?
# 2    2024-01-27 06:25:13     Tesla is going to fall to between $100 & $150.
# 3    2024-01-28 05:04:35  How are they long-term resilient if they're do...
# 4    2024-01-27 07:20:17  Welcome to r/stockmarket.\n\nIt's all just bot...
# ...                  ...                                                ...
# 4099 2024-01-17 04:40:50                           Is he worth 20 Twitters?
# 4100 2024-01-17 00:53:22  Simply asked? Bruh, you went on a rant and cal...
# 4101 2024-01-17 01:06:35  haha "blue haired retar\*d" I like that. I'm g...
# 4102 2024-01-17 01:44:27          Your reading comprehension is impressive.
# 4103 2024-01-17 02:18:07                                        danke schön
#
#       upvotes
# 0          24
# 1           3
# 2          -8
# 3           1
# 4           5
# ...       ...
# 4099        1
# 4100        1
# 4101        1
# 4102       -1
# 4103       -1
#
# [3348 rows x 5 columns]

# %%
df = df.drop_duplicates(subset='comment_text')
df
# Out:
#      submission_id                                   submission_title  \
# 0          1abv5ee                           Routine Analysis of TSLA
# 1          1abv5ee                           Routine Analysis of TSLA
# 2          1abv5ee                           Routine Analysis of TSLA
# 3          1abv5ee                           Routine Analysis of TSLA
# 4          1abv5ee                           Routine Analysis of TSLA
# ...            ...                                                ...
# 4099       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4100       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4101       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4102       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4103       197p6vu  remember when elon pumped $TSLA instead of dum...
#
#                     date                                       comment_text  \
# 0    2024-01-27 06:48:36         This is such a generic and pointless post.
# 1    2024-01-27 19:02:34      thanks for summarizing yahoo finance I guess?
# 2    2024-01-27 06:25:13     Tesla is going to fall to between $100 & $150.
# 3    2024-01-28 05:04:35  How are they long-term resilient if they're do...
# 4    2024-01-27 07:20:17  Welcome to r/stockmarket.\n\nIt's all just bot...
# ...                  ...                                                ...
# 4099 2024-01-17 04:40:50                           Is he worth 20 Twitters?
# 4100 2024-01-17 00:53:22  Simply asked? Bruh, you went on a rant and cal...
# 4101 2024-01-17 01:06:35  haha "blue haired retar\*d" I like that. I'm g...
# 4102 2024-01-17 01:44:27          Your reading comprehension is impressive.
# 4103 2024-01-17 02:18:07                                        danke schön
#
#       upvotes
# 0          24
# 1           3
# 2          -8
# 3           1
# 4           5
# ...       ...
# 4099        1
# 4100        1
# 4101        1
# 4102       -1
# 4103       -1
#
# [3223 rows x 5 columns]

# %%
# Define a function to clean the text
def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+', ' ', text)
    return text

# Cleaning the text in the review column
df['cleaned comment_text'] = df['comment_text'].apply(clean)
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20620\1422020617.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned comment_text'] = df['comment_text'].apply(clean)
#      submission_id                                   submission_title  \
# 0          1abv5ee                           Routine Analysis of TSLA
# 1          1abv5ee                           Routine Analysis of TSLA
# 2          1abv5ee                           Routine Analysis of TSLA
# 3          1abv5ee                           Routine Analysis of TSLA
# 4          1abv5ee                           Routine Analysis of TSLA
# ...            ...                                                ...
# 4099       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4100       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4101       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4102       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4103       197p6vu  remember when elon pumped $TSLA instead of dum...
#
#                     date                                       comment_text  \
# 0    2024-01-27 06:48:36         This is such a generic and pointless post.
# 1    2024-01-27 19:02:34      thanks for summarizing yahoo finance I guess?
# 2    2024-01-27 06:25:13     Tesla is going to fall to between $100 & $150.
# 3    2024-01-28 05:04:35  How are they long-term resilient if they're do...
# 4    2024-01-27 07:20:17  Welcome to r/stockmarket.\n\nIt's all just bot...
# ...                  ...                                                ...
# 4099 2024-01-17 04:40:50                           Is he worth 20 Twitters?
# 4100 2024-01-17 00:53:22  Simply asked? Bruh, you went on a rant and cal...
# 4101 2024-01-17 01:06:35  haha "blue haired retar\*d" I like that. I'm g...
# 4102 2024-01-17 01:44:27          Your reading comprehension is impressive.
# 4103 2024-01-17 02:18:07                                        danke schön
#
#       upvotes                               cleaned comment_text
# 0          24         This is such a generic and pointless post
# 1           3      thanks for summarizing yahoo finance I guess
# 2          -8                 Tesla is going to fall to between
# 3           1  How are they long term resilient if they re do...
# 4           5  Welcome to r stockmarket It s all just bots AI...
# ...       ...                                                ...
# 4099        1                              Is he worth Twitters
# 4100        1  Simply asked Bruh you went on a rant and calle...
# 4101        1  haha blue haired retar d I like that I m gonna...
# 4102       -1          Your reading comprehension is impressive
# 4103       -1                                        danke sch n
#
# [3223 rows x 6 columns]

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# Load the English stopwords
stop_words = set(stopwords.words('english'))

# Function to remove stopwords from a text
def remove_stopwords(text):
    text = str(text)
    word_tokens = word_tokenize(text)  # Tokenize the text into words
    filtered_sentence = [word for word in word_tokens if word.casefold()  not in stop_words]  # Remove stopwords
    return ' '.join(filtered_sentence)  # Join the words back into a sentence

# %%
# Apply the function to the 'comment_text' column
df['no_sw_cmt'] = df['cleaned comment_text'].apply(remove_stopwords)
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20620\944318457.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['no_sw_cmt'] = df['cleaned comment_text'].apply(remove_stopwords)
#      submission_id                                   submission_title  \
# 0          1abv5ee                           Routine Analysis of TSLA
# 1          1abv5ee                           Routine Analysis of TSLA
# 2          1abv5ee                           Routine Analysis of TSLA
# 3          1abv5ee                           Routine Analysis of TSLA
# 4          1abv5ee                           Routine Analysis of TSLA
# ...            ...                                                ...
# 4099       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4100       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4101       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4102       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4103       197p6vu  remember when elon pumped $TSLA instead of dum...
#
#                     date                                       comment_text  \
# 0    2024-01-27 06:48:36         This is such a generic and pointless post.
# 1    2024-01-27 19:02:34      thanks for summarizing yahoo finance I guess?
# 2    2024-01-27 06:25:13     Tesla is going to fall to between $100 & $150.
# 3    2024-01-28 05:04:35  How are they long-term resilient if they're do...
# 4    2024-01-27 07:20:17  Welcome to r/stockmarket.\n\nIt's all just bot...
# ...                  ...                                                ...
# 4099 2024-01-17 04:40:50                           Is he worth 20 Twitters?
# 4100 2024-01-17 00:53:22  Simply asked? Bruh, you went on a rant and cal...
# 4101 2024-01-17 01:06:35  haha "blue haired retar\*d" I like that. I'm g...
# 4102 2024-01-17 01:44:27          Your reading comprehension is impressive.
# 4103 2024-01-17 02:18:07                                        danke schön
#
#       upvotes                               cleaned comment_text  \
# 0          24         This is such a generic and pointless post
# 1           3      thanks for summarizing yahoo finance I guess
# 2          -8                 Tesla is going to fall to between
# 3           1  How are they long term resilient if they re do...
# 4           5  Welcome to r stockmarket It s all just bots AI...
# ...       ...                                                ...
# 4099        1                              Is he worth Twitters
# 4100        1  Simply asked Bruh you went on a rant and calle...
# 4101        1  haha blue haired retar d I like that I m gonna...
# 4102       -1          Your reading comprehension is impressive
# 4103       -1                                        danke sch n
#
#                                               no_sw_cmt
# 0                                generic pointless post
# 1                thanks summarizing yahoo finance guess
# 2                                      Tesla going fall
# 3     long term resilient year chart underperforming...
# 4     Welcome r stockmarket bots AI wannabe shills t...
# ...                                                 ...
# 4099                                     worth Twitters
# 4100  Simply asked Bruh went rant called blue haired...
# 4101             haha blue haired retar like gon na use
# 4102                   reading comprehension impressive
# 4103                                        danke sch n
#
# [3223 rows x 7 columns]

# %%
df = df[~(df.apply(lambda row: (row == 'deleted').all(), axis=1))]
df
# Out:
#      submission_id                                   submission_title  \
# 0          1abv5ee                           Routine Analysis of TSLA
# 1          1abv5ee                           Routine Analysis of TSLA
# 2          1abv5ee                           Routine Analysis of TSLA
# 3          1abv5ee                           Routine Analysis of TSLA
# 4          1abv5ee                           Routine Analysis of TSLA
# ...            ...                                                ...
# 4099       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4100       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4101       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4102       197p6vu  remember when elon pumped $TSLA instead of dum...
# 4103       197p6vu  remember when elon pumped $TSLA instead of dum...
#
#                     date                                       comment_text  \
# 0    2024-01-27 06:48:36         This is such a generic and pointless post.
# 1    2024-01-27 19:02:34      thanks for summarizing yahoo finance I guess?
# 2    2024-01-27 06:25:13     Tesla is going to fall to between $100 & $150.
# 3    2024-01-28 05:04:35  How are they long-term resilient if they're do...
# 4    2024-01-27 07:20:17  Welcome to r/stockmarket.\n\nIt's all just bot...
# ...                  ...                                                ...
# 4099 2024-01-17 04:40:50                           Is he worth 20 Twitters?
# 4100 2024-01-17 00:53:22  Simply asked? Bruh, you went on a rant and cal...
# 4101 2024-01-17 01:06:35  haha "blue haired retar\*d" I like that. I'm g...
# 4102 2024-01-17 01:44:27          Your reading comprehension is impressive.
# 4103 2024-01-17 02:18:07                                        danke schön
#
#       upvotes                               cleaned comment_text  \
# 0          24         This is such a generic and pointless post
# 1           3      thanks for summarizing yahoo finance I guess
# 2          -8                 Tesla is going to fall to between
# 3           1  How are they long term resilient if they re do...
# 4           5  Welcome to r stockmarket It s all just bots AI...
# ...       ...                                                ...
# 4099        1                              Is he worth Twitters
# 4100        1  Simply asked Bruh you went on a rant and calle...
# 4101        1  haha blue haired retar d I like that I m gonna...
# 4102       -1          Your reading comprehension is impressive
# 4103       -1                                        danke sch n
#
#                                               no_sw_cmt
# 0                                generic pointless post
# 1                thanks summarizing yahoo finance guess
# 2                                      Tesla going fall
# 3     long term resilient year chart underperforming...
# 4     Welcome r stockmarket bots AI wannabe shills t...
# ...                                                 ...
# 4099                                     worth Twitters
# 4100  Simply asked Bruh went rant called blue haired...
# 4101             haha blue haired retar like gon na use
# 4102                   reading comprehension impressive
# 4103                                        danke sch n
#
# [3223 rows x 7 columns]

# %%
df.to_csv('tsla_cleaned.csv', index=False)

# %%
print(df.dtypes)
# Out:
# submission_id                   object
# submission_title                object
# date                    datetime64[ns]
# comment_text                    object
# upvotes                          int64
# cleaned comment_text            object
# no_sw_cmt                       object
# dtype: object

# %%
df1=pd.read_csv('tsla_merged1.csv')
print(df1.dtypes)
# Out:
# submission_id       object
# submission_title    object
# date                object
# comment_text        object
# upvotes              int64
# dtype: object
