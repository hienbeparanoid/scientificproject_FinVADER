# %%
from google.colab import drive
drive.mount('/content/gdrive')

import pandas as pd
df1 = pd.read_csv('/content/gdrive/My Drive/mergefile/AAPL/stockmarket_aapl_comments.csv')
df2 = pd.read_csv('/content/gdrive/My Drive/mergefile/AAPL/stocks_aapl_comments.csv')
df3 = pd.read_csv('/content/gdrive/My Drive/mergefile/AAPL/wallstreetbets_aapl_comments.csv')

df4= pd.read_csv('/content/gdrive/My Drive/mergefile/AMD/stockmarket_amd_comments.csv')
df5= pd.read_csv('/content/gdrive/My Drive/mergefile/AMD/stocks_amd_comments.csv')
df6= pd.read_csv('/content/gdrive/My Drive/mergefile/AMD/wallstreetbets_amd_comments.csv')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # **AAPL**

# %%
merged_df_aapl = pd.concat([df1, df2, df3], ignore_index=True)

# %%
merged_df_aapl.head(10)
# Out:
#   submission_id                                   submission_title  \
# 0       17sz3xi  Trying to understand this chart. Massive AAPL ...
# 1       17sz3xi  Trying to understand this chart. Massive AAPL ...
# 2       17sz3xi  Trying to understand this chart. Massive AAPL ...
# 3       17sz3xi  Trying to understand this chart. Massive AAPL ...
# 4       17sz3xi  Trying to understand this chart. Massive AAPL ...
# 5       17sz3xi  Trying to understand this chart. Massive AAPL ...
# 6       17sz3xi  Trying to understand this chart. Massive AAPL ...
# 7       17sz3xi  Trying to understand this chart. Massive AAPL ...
# 8       17sz3xi  Trying to understand this chart. Massive AAPL ...
# 9       17sz3xi  Trying to understand this chart. Massive AAPL ...
#
#                                         comment_text  upvotes
# 0  Looks fine to me. The large institutional inve...       13
# 1  you need to investigate opening and closing pr...       10
# ...

# %%
merged_df_aapl.shape
# Out:
# (1285, 4)

# %%
merged_df_aapl.to_csv("AAPL.csv")

# %% [markdown]
# # **AMD**

# %%
merged_df_amd = pd.concat([df4, df5, df6], ignore_index=True)

# %%
merged_df_amd.head(10)
# Out:
#   submission_id                                   submission_title  \
# 0       17scpov  $NVDA $AMD rise - Chip gains as sector ending ...
# 1       17scpov  $NVDA $AMD rise - Chip gains as sector ending ...
# 2       17scpov  $NVDA $AMD rise - Chip gains as sector ending ...
# 3       17scpov  $NVDA $AMD rise - Chip gains as sector ending ...
# 4       17leoks                                  Thoughts on $AMD?
# 5       17leoks                                  Thoughts on $AMD?
# 6       17leoks                                  Thoughts on $AMD?
# 7       17leoks                                  Thoughts on $AMD?
# 8       17leoks                                  Thoughts on $AMD?
# 9       17leoks                                  Thoughts on $AMD?
#
#                                         comment_text  upvotes
# 0  The surge today was due to TSM's monthly reven...        3
# 1         How is Nvidia selling to Chinese startups?        2
# ...

# %%
merged_df_amd.shape
# Out:
# (381, 4)

# %%
merged_df_amd.to_csv("AMD.csv")

# %% [markdown]
# # **MSFT**

# %%
df7= pd.read_csv('/content/gdrive/My Drive/mergefile/MSFT/stockmarket_msft_comments.csv')
df8= pd.read_csv('/content/gdrive/My Drive/mergefile/MSFT/stocks_msft_comments.csv')
df9= pd.read_csv('/content/gdrive/My Drive/mergefile/MSFT/wallstreetbets_msft_comments.csv')

# %%
merged_df_msft = pd.concat([df7, df8, df9], ignore_index=True)

# %%
merged_df_msft.head(10)
# Out:
#   submission_id                   submission_title  \
# 0       17s8uuv  Microsoft $MSFT at all time high!
# 1       17s8uuv  Microsoft $MSFT at all time high!
# 2       17s8uuv  Microsoft $MSFT at all time high!
# 3       17s8uuv  Microsoft $MSFT at all time high!
# 4       17s8uuv  Microsoft $MSFT at all time high!
# 5       17s8uuv  Microsoft $MSFT at all time high!
# 6       17s8uuv  Microsoft $MSFT at all time high!
# 7       17s8uuv  Microsoft $MSFT at all time high!
# 8       17s8uuv  Microsoft $MSFT at all time high!
# 9       17s8uuv  Microsoft $MSFT at all time high!
#
#                                         comment_text  upvotes
# 0  I've later regretted every time that I sold it...       49
# 1  Sold my position at an average of $312. This i...       86
# 2  They can even de-throne Apple in case AI hype ...      109
# 3  In time, Microsoft will be more valuable than ...       11
# 4  I bought it during Covid on the way up.\nI thi...       10
# ...

# %%
merged_df_msft.shape
# Out:
# (1264, 4)

# %%
merged_df_msft.to_csv("MSFT.csv")

# %% [markdown]
# # **NIO**

# %%
df10= pd.read_csv('/content/gdrive/My Drive/mergefile/NIO/stockmarket_nio_comments.csv')
df11= pd.read_csv('/content/gdrive/My Drive/mergefile/NIO/stocks_nio_comments.csv')
df12= pd.read_csv('/content/gdrive/My Drive/mergefile/NIO/wallstreetbets_nio_comments.csv')

# %%
merged_df_nio = pd.concat([df10, df11, df12], ignore_index=True)

# %%
merged_df_nio.head(10)
# Out:
#   submission_id submission_title  \
# 0       18hzuzp        Opinions?
# 1       18hzuzp        Opinions?
# 2       18hzuzp        Opinions?
# 3       18hzuzp        Opinions?
# 4       18hzuzp        Opinions?
# 5       18hzuzp        Opinions?
# 6       18hzuzp        Opinions?
# 7       18hzuzp        Opinions?
# 8       18hzuzp        Opinions?
# 9       18hzuzp        Opinions?
#
#                                         comment_text  upvotes
# 0  First of all congratulations on starting early...       11
# 1               Put it all in VOO and you’ll be good        3
# 2       Put all your money in ONE single S&P 500 ETF        3
# 3                             opinions don't matter.        2
# 4  Please stop buying QYLD. This thing doesn’t ma...        2
# 5                                 You need some BRCC        1
# 6  My opinion is that you should get off Robbinghood       -2
# 7                                        Sell it all        0
# ...

# %%
merged_df_nio.shape
# Out:
# (872, 4)

# %%
merged_df_nio.to_csv("NIO.csv")

# %% [markdown]
# # **TSLA**

# %%
df13= pd.read_csv('/content/gdrive/My Drive/mergefile/TSLA/stockmarket_tsla_comments.csv')
df14= pd.read_csv('/content/gdrive/My Drive/mergefile/TSLA/stocks_tsla_comments.csv')
df15= pd.read_csv('/content/gdrive/My Drive/mergefile/TSLA/wallstreetbets_tsla_comments.csv')

# %%
merged_df_tsla = pd.concat([df13, df14, df15], ignore_index=True)

# %%
merged_df_tsla.head(10)
# Out:
#   submission_id                                   submission_title  \
# 0       1867wce                                        TSLA Bulish
# 1       1867wce                                        TSLA Bulish
# 2       180pzw2  Sold 1/3 of my TSLA shares so I could feed bab...
# 3       180pzw2  Sold 1/3 of my TSLA shares so I could feed bab...
# 4       180pzw2  Sold 1/3 of my TSLA shares so I could feed bab...
# 5       180pzw2  Sold 1/3 of my TSLA shares so I could feed bab...
# 6       180pzw2  Sold 1/3 of my TSLA shares so I could feed bab...
# 7       180pzw2  Sold 1/3 of my TSLA shares so I could feed bab...
# 8       180pzw2  Sold 1/3 of my TSLA shares so I could feed bab...
# 9       180pzw2  Sold 1/3 of my TSLA shares so I could feed bab...
#
#                                         comment_text  upvotes
# 0                     Expecting a 10-point pop today        1
# 1                      Well, this didn't age well...        2
# ...

# %%
merged_df_tsla.shape
# Out:
# (2336, 4)

# %%
merged_df_tsla.to_csv("TSLA.csv")
