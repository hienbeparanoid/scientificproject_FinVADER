# %%
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# data_tsla = yf.download(tickers='TSLA', start='2023-12-30', end='2024-1-29', interval='30m')
# data_tsla
# data_tsla.dropna()
# data_tsla
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                            Open        High         Low       Close  \
# Datetime
# 2024-01-02 09:30:00  250.080002  250.899994  244.410004  248.794006
# 2024-01-02 10:00:00  248.779999  251.250000  248.050003  249.610001
# 2024-01-02 10:30:00  249.600006  249.638199  246.820007  248.919998
# 2024-01-02 11:00:00  248.899994  250.259995  248.339996  250.000000
# 2024-01-02 11:30:00  249.994095  251.000000  249.900101  250.475403
# ...                         ...         ...         ...         ...
# 2024-01-26 13:30:00  183.490097  183.630005  182.291000  182.644394
# 2024-01-26 14:00:00  182.654999  182.660004  182.100006  182.280106
# 2024-01-26 14:30:00  182.300003  183.380005  182.119995  183.270004
# 2024-01-26 15:00:00  183.270004  183.320007  182.380005  182.630005
# 2024-01-26 15:30:00  182.629898  183.470001  182.610001  183.229904
#
#                       Adj Close    Volume
# Datetime
# 2024-01-02 09:30:00  248.794006  22581347
# 2024-01-02 10:00:00  249.610001  13845933
# 2024-01-02 10:30:00  248.919998  10503013
# 2024-01-02 11:00:00  250.000000   6429840
# 2024-01-02 11:30:00  250.475403   6197232
# ...                         ...       ...
# 2024-01-26 13:30:00  182.644394   5029161
# 2024-01-26 14:00:00  182.280106   3917711
# 2024-01-26 14:30:00  183.270004   4844718
# 2024-01-26 15:00:00  182.630005   5169574
# 2024-01-26 15:30:00  183.229904   7488537
#
# [234 rows x 6 columns]

# %%
data_tsla = pd.read_csv('data_tsla.csv')
data_tsla
# Out:
#                 Datetime        Open        High         Low       Close  \
# 0    2024-01-02 09:30:00  250.080002  250.899994  244.410004  248.794006
# 1    2024-01-02 10:00:00  248.779999  251.250000  248.050003  249.610001
# 2    2024-01-02 10:30:00  249.600006  249.638199  246.820007  248.919998
# 3    2024-01-02 11:00:00  248.899994  250.259995  248.339996  250.000000
# 4    2024-01-02 11:30:00  249.994095  251.000000  249.900101  250.475403
# ..                   ...         ...         ...         ...         ...
# 229  2024-01-26 13:30:00  183.490097  183.630005  182.291000  182.644394
# 230  2024-01-26 14:00:00  182.654999  182.660004  182.100006  182.280106
# 231  2024-01-26 14:30:00  182.300003  183.380005  182.119995  183.270004
# 232  2024-01-26 15:00:00  183.270004  183.320007  182.380005  182.630005
# 233  2024-01-26 15:30:00  182.629898  183.470001  182.610001  183.229904
#
#       Adj Close    Volume
# 0    248.794006  22581347
# 1    249.610001  13845933
# 2    248.919998  10503013
# 3    250.000000   6429840
# 4    250.475403   6197232
# ..          ...       ...
# 229  182.644394   5029161
# 230  182.280106   3917711
# 231  183.270004   4844718
# 232  182.630005   5169574
# 233  183.229904   7488537
#
# [234 rows x 7 columns]

# %%
data_tsla = data_tsla.set_index('Datetime')
data_tsla
print(data_tsla.dtypes)
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#SMA
data_tsla['2_SMA'] = data_tsla['Close'].rolling(window=2).mean() #trung binh cua 2 gtri lien tiep
data_tsla['5_SMA'] = data_tsla['Close'].rolling(window=5).mean() #trung binh cua 5 gtri lien tiep

data_tsla = data_tsla[data_tsla['5_SMA'].notna()]
data_tsla
# Out:
#                            Open        High         Low       Close  \
# Datetime
# 2024-01-02 11:30:00  249.994095  251.000000  249.900101  250.475403
# 2024-01-02 12:00:00  250.449997  250.660004  247.941696  248.350006
# 2024-01-02 12:30:00  248.354996  249.132996  247.490005  247.581406
# 2024-01-02 13:00:00  247.583801  248.720001  247.000000  248.351700
# 2024-01-02 13:30:00  248.389999  249.380005  247.949997  248.248398
# ...                         ...         ...         ...         ...
# 2024-01-26 13:30:00  183.490097  183.630005  182.291000  182.644394
# 2024-01-26 14:00:00  182.654999  182.660004  182.100006  182.280106
# 2024-01-26 14:30:00  182.300003  183.380005  182.119995  183.270004
# 2024-01-26 15:00:00  183.270004  183.320007  182.380005  182.630005
# 2024-01-26 15:30:00  182.629898  183.470001  182.610001  183.229904
#
#                       Adj Close   Volume       2_SMA       5_SMA
# Datetime
# 2024-01-02 11:30:00  250.475403  6197232  250.237701  249.559882
# 2024-01-02 12:00:00  248.350006  5924493  249.412704  249.471082
# 2024-01-02 12:30:00  247.581406  4590789  247.965706  249.065363
# 2024-01-02 13:00:00  248.351700  4709374  247.966553  248.951703
# 2024-01-02 13:30:00  248.248398  4269095  248.300049  248.601382
# ...                         ...      ...         ...         ...
# 2024-01-26 13:30:00  182.644394  5029161  183.062195  183.716278
# 2024-01-26 14:00:00  182.280106  3917711  182.462250  183.252100
# 2024-01-26 14:30:00  183.270004  4844718  182.775055  183.085101
# 2024-01-26 15:00:00  182.630005  5169574  182.950005  182.860901
# 2024-01-26 15:30:00  183.229904  7488537  182.929955  182.810883
#
# [230 rows x 8 columns]

# %%
# SMA trade calls
Trade_Buy=[]
Trade_Sell=[]
for i in range(len(data_tsla)-1):
    if ((data_tsla['2_SMA'].values[i] < data_tsla['5_SMA'].values[i]) & (data_tsla['2_SMA'].values[i+1] > data_tsla['5_SMA'].values[i+1])):
        print("Trade Call for {row} is Buy.".format(row=data_tsla.index[i]))
        Trade_Buy.append(i)
    elif ((data_tsla['2_SMA'].values[i] > data_tsla['5_SMA'].values[i]) & (data_tsla['2_SMA'].values[i+1] < data_tsla['5_SMA'].values[i+1])):
        print("Trade Call for {row} is Sell.".format(row=data_tsla.index[i]))
        Trade_Sell.append(i)

print(Trade_Buy)
print(Trade_Sell)
# Out:
# Trade Call for 2024-01-02 11:30:00 is Sell.
# Trade Call for 2024-01-02 13:30:00 is Buy.
# Trade Call for 2024-01-02 14:00:00 is Sell.
# Trade Call for 2024-01-03 11:00:00 is Buy.
# Trade Call for 2024-01-03 13:00:00 is Sell.
# Trade Call for 2024-01-03 13:30:00 is Buy.
# Trade Call for 2024-01-03 14:00:00 is Sell.
# Trade Call for 2024-01-04 09:30:00 is Buy.
# Trade Call for 2024-01-04 11:30:00 is Sell.
# Trade Call for 2024-01-04 13:00:00 is Buy.
# Trade Call for 2024-01-04 13:30:00 is Sell.
# Trade Call for 2024-01-05 10:00:00 is Buy.
# Trade Call for 2024-01-05 11:00:00 is Sell.
# Trade Call for 2024-01-05 13:00:00 is Buy.
# Trade Call for 2024-01-05 14:00:00 is Sell.
# Trade Call for 2024-01-05 15:30:00 is Buy.
# Trade Call for 2024-01-08 10:00:00 is Sell.
# Trade Call for 2024-01-08 11:00:00 is Buy.
# Trade Call for 2024-01-08 15:30:00 is Sell.
# Trade Call for 2024-01-09 11:00:00 is Buy.
# Trade Call for 2024-01-09 12:30:00 is Sell.
# Trade Call for 2024-01-09 14:30:00 is Buy.
# Trade Call for 2024-01-09 15:30:00 is Sell.
# Trade Call for 2024-01-10 12:30:00 is Buy.
# Trade Call for 2024-01-10 15:00:00 is Sell.
# Trade Call for 2024-01-11 12:30:00 is Buy.
# Trade Call for 2024-01-11 15:30:00 is Sell.
# Trade Call for 2024-01-12 13:00:00 is Buy.
# Trade Call for 2024-01-12 13:30:00 is Sell.
# Trade Call for 2024-01-12 15:00:00 is Buy.
# Trade Call for 2024-01-16 11:00:00 is Sell.
# Trade Call for 2024-01-16 12:30:00 is Buy.
# Trade Call for 2024-01-16 14:00:00 is Sell.
# Trade Call for 2024-01-17 11:30:00 is Buy.
# Trade Call for 2024-01-17 12:30:00 is Sell.
# Trade Call for 2024-01-17 14:00:00 is Buy.
# Trade Call for 2024-01-18 10:00:00 is Sell.
# Trade Call for 2024-01-18 13:30:00 is Buy.
# Trade Call for 2024-01-19 09:30:00 is Sell.
# Trade Call for 2024-01-19 12:00:00 is Buy.
# Trade Call for 2024-01-22 10:00:00 is Sell.
# Trade Call for 2024-01-22 14:30:00 is Buy.
# Trade Call for 2024-01-23 10:30:00 is Sell.
# Trade Call for 2024-01-23 14:30:00 is Buy.
# Trade Call for 2024-01-24 12:00:00 is Sell.
# Trade Call for 2024-01-25 14:00:00 is Buy.
# Trade Call for 2024-01-26 11:00:00 is Sell.
# Trade Call for 2024-01-26 14:30:00 is Buy.
# [4, 12, 17, 22, 29, 36, 42, 47, 51, 64, 71, 80, 93, 107, 111, 119, 130, 135, 147, 157, 175, 188, 213, 227]
# [0, 5, 16, 18, 26, 30, 38, 44, 49, 60, 67, 73, 85, 99, 108, 116, 122, 132, 140, 152, 166, 180, 196, 220]

# %%
with open('output.txt', 'w') as f:
    for i in range(len(data_tsla)-1):
        if ((data_tsla['2_SMA'].values[i] < data_tsla['5_SMA'].values[i]) & (data_tsla['2_SMA'].values[i+1] > data_tsla['5_SMA'].values[i+1])):
            f.write("Trade Call for {row} is Buy.\n".format(row=data_tsla.index[i].date()))
            Trade_Buy.append(i)
        elif ((data_tsla['2_SMA'].values[i] > data_tsla['5_SMA'].values[i]) & (data_tsla['2_SMA'].values[i+1] < data_tsla['5_SMA'].values[i+1])):
            f.write("Trade Call for {row} is Sell.\n".format(row=data_tsla.index[i].date()))

# %%
# Visualizing SMA trade calls
plt.style.use('ggplot')
plt.figure(figsize=(20, 10),dpi=80)
plt.plot(data_tsla.index, data_tsla['Close'], color = 'purple', lw=1)
plt.plot(data_tsla.index, data_tsla['2_SMA'],'-^', markevery=Trade_Buy, ms=10, color='green', lw=1)
plt.plot(data_tsla.index, data_tsla['5_SMA'],'-v', markevery=Trade_Sell, ms=10, color='red', lw=1)
plt.xlabel('Date',fontsize=14)
plt.ylabel('Price in Dollars', fontsize = 14)
plt.xticks(rotation=60,fontsize=12)
plt.yticks(fontsize=12)
plt.title('Trade Calls - Moving Averages Crossover', fontsize = 16)
plt.legend(['Close','2_SMA','5_SMA'])
plt.grid(True)
plt.show()

# %%
print(Trade_Buy)
print(Trade_Sell)
# Out:
# [4, 12, 17, 22, 29, 36, 42, 47, 51, 64, 71, 80, 93, 107, 111, 119, 130, 135, 147, 157, 175, 188, 213, 227, 4, 12, 17, 22, 29, 36, 42, 47, 51, 64, 71, 80, 93, 107, 111, 119, 130, 135, 147, 157, 175, 188, 213, 227]
# [0, 5, 16, 18, 26, 30, 38, 44, 49, 60, 67, 73, 85, 99, 108, 116, 122, 132, 140, 152, 166, 180, 196, 220]
